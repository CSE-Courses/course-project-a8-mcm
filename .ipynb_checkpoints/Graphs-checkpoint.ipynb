# %%
# Import webscraped data 
from webscrape import *

# Importing numpy and panda packages
import numpy as np
import pandas as pd

# Data Visualization
import matplotlib.pyplot as plt
import mplfinance as mpf

# Training and testing package
from sklearn.model_selection import train_test_split

# Linear Regression Model
from sklearn.linear_model import LinearRegression

# Allows plot to appear directly in notebook
# %matplotlib inline

# %%
# Asking user for stock they want to look up
url = get_url("aapl")

# Write the data into csv form and gives it as output.csv
write_to_csv(url)

# %%
# Read data into a dataframe using panda
df = pd.read_csv('output.csv', index_col=0, parse_dates=True)
# Reversed the data to have the oldest date and data at the top and newest at the bottom
df = df.reindex(index=df.index[::-1])
df
# Out:
#               Open    High     Low   Close  Adj Close     Volume
# Date
# 2020-05-28   79.19   80.86   78.91   79.56      79.42  133560800
# 2020-05-29   79.81   80.29   79.12   79.49      79.34  153598000
# 2020-06-01   79.44   80.59   79.30   80.46      80.32   80791200
# 2020-06-02   80.19   80.86   79.73   80.83      80.69   87642800
# 2020-06-03   81.17   81.55   80.57   81.28      81.13  104491200
# ...            ...     ...     ...     ...        ...        ...
# 2020-10-08  116.25  116.40  114.59  114.97     114.97   83477200
# 2020-10-09  115.28  117.00  114.92  116.97     116.97  100506900
# 2020-10-12  120.06  125.18  119.28  124.40     124.40  240226800
# 2020-10-13  125.27  125.39  119.65  121.10     121.10  261686100
# 2020-10-14  121.00  123.03  119.62  121.19     121.19  151062308
#
# [98 rows x 6 columns]

# %%
df.plot(y="Close", ylabel="Price", title=get_company_name(url), rot=90)
plt.savefig("line.png")

# %%
mpf.plot(df, type='candle', style='charles', title=get_company_name(url), ylabel="Price", savefig="candlestick.png")
